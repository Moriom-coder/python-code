# %%
import numpy
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = random.normal(size=1000)

# %%
x = random.normal(size=(2,3))

# %%
x=random.normal(loc=1,scale=2,size=(2,3))

# %%
print(x)
# Out:
# [[-0.7858068   2.01514676 -0.20720455]
#  [-0.3296988  -1.13322563 -2.36201302]]

# %%
sns.distplot(random.normal(size=1000),hist=True)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11484\3027405487.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=True)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=False)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_25584\3728753053.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=False)

# %%
import pandas as pd
print(pd.__version__)
mydataset={
    'cars':["BMW","Volvo","Ford"],
    'passings':[3,7,2]
}
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
# 2.3.1
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
calories={"day1":420,"day2":380,"day3":350}
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    350
# dtype: int64

# %%
#url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
url="https://raw.githubusercontent.com/vizydrop/data-samples/master/flowers.csv"
df=pd.read_csv(url)
print(df)
# Out:
#      sepal length  sepal width  petal length  petal width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
counts=dict()
print('Enter a line of text')
line=input("hello this is me")

words=line.split()
print('words:',words)

print('Counting....')
for word in words:
  counts[word]=counts.get(word,0)+1
print('Counts',counts)
# Out:
# Enter a line of text
